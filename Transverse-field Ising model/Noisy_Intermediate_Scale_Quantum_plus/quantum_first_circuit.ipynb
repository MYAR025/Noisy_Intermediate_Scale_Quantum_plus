# %%
# !pip install qiskit qiskit-ibm-runtime -q

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

QiskitRuntimeService.save_account(
    token="<your-api-key>",
    instance="<your-CRN>",
    overwrite=True
)

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

# Run every time you need the service
service = QiskitRuntimeService()
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/qiskit_ibm_runtime/accounts/account.py in list_instances(self)
#     351             try:
# --> 352                 result = client.search(
#     353                     query="service_name:quantum-computing",
#
# /usr/local/lib/python3.12/dist-packages/ibm_platform_services/global_search_v2.py in search(self, query, fields, search_cursor, x_request_id, x_correlation_id, account_id, limit, timeout, sort, is_deleted, is_reclaimed, impersonate_user, can_tag, is_project_resource, **kwargs)
#     227         url = '/v3/resources/search'
# --> 228         request = self.prepare_request(
#     229             method='POST',
#
# /usr/local/lib/python3.12/dist-packages/ibm_cloud_sdk_core/base_service.py in prepare_request(self, method, url, headers, params, data, files, **kwargs)
#     440
# --> 441         self.authenticator.authenticate(request)
#     442
#
# /usr/local/lib/python3.12/dist-packages/ibm_cloud_sdk_core/authenticators/iam_request_based_authenticator.py in authenticate(self, req)
#      63         headers = req.get('headers')
# ---> 64         bearer_token = self.token_manager.get_token()
#      65         headers['Authorization'] = 'Bearer {0}'.format(bearer_token)
#
# /usr/local/lib/python3.12/dist-packages/ibm_cloud_sdk_core/token_managers/token_manager.py in get_token(self)
#      81             logger.debug('Performing synchronous token fetch')
# ---> 82             self.paced_request_token()
#      83
#
# /usr/local/lib/python3.12/dist-packages/ibm_cloud_sdk_core/token_managers/token_manager.py in paced_request_token(self)
#     140             if not request_active:
# --> 141                 token_response = self.request_token()
#     142                 self._save_token_info(token_response)
#
# /usr/local/lib/python3.12/dist-packages/ibm_cloud_sdk_core/token_managers/iam_request_based_token_manager.py in request_token(self)
#     126         logger.debug('Invoking IAM get_token operation: %s', request_url)
# --> 127         response = self._request(
#     128             method='POST',
#
# /usr/local/lib/python3.12/dist-packages/ibm_cloud_sdk_core/token_managers/jwt_token_manager.py in _request(self, method, url, headers, params, data, auth_tuple, **kwargs)
#      90
# ---> 91         raise ApiException(response.status_code, http_response=response)
#
# ApiException: Error: Provided API key could not be found., Status code: 400
#
# The above exception was the direct cause of the following exception:
#
# InvalidAccountError                       Traceback (most recent call last)
# /tmp/ipykernel_676/1952727273.py in <cell line: 0>()
#       2
#       3 # Run every time you need the service
# ----> 4 service = QiskitRuntimeService()
#
# /usr/local/lib/python3.12/dist-packages/qiskit_ibm_runtime/qiskit_runtime_service.py in __init__(self, channel, token, url, filename, name, instance, proxies, verify, private_endpoint, url_resolver, region, plans_preference, tags)
#     224         if self._instance_auto:
#     225             instance = None
# --> 226         self._account = self._discover_account(
#     227             token=token,
#     228             url=url,
#
# /usr/local/lib/python3.12/dist-packages/qiskit_ibm_runtime/qiskit_runtime_service.py in _discover_account(self, token, url, instance, channel, filename, name, proxies, verify)
#     478             and not is_crn(account.instance)
#     479         ):
# --> 480             account.instance = self._get_crn_from_instance_name(
#     481                 account=account, instance=account.instance
#     482             )
#
# /usr/local/lib/python3.12/dist-packages/qiskit_ibm_runtime/qiskit_runtime_service.py in _get_crn_from_instance_name(self, account, instance)
#     490         """Get the crn from the instance service name."""
#     491         if not self._all_instances:
# --> 492             self._all_instances = account.list_instances()
#     493         matching_instances = [item for item in self._all_instances if item["name"] == instance]
#     494         if matching_instances:
#
# /usr/local/lib/python3.12/dist-packages/qiskit_ibm_runtime/accounts/account.py in list_instances(self)
#     365                 ).get_result()
#     366             except Exception as ex:
# --> 367                 raise InvalidAccountError(
#     368                     "Unable to retrieve instances. "
#     369                     "Please check that you are using a valid API token."
#
# InvalidAccountError: 'Unable to retrieve instances. Please check that you are using a valid API token.'

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import SparsePauliOp
from qiskit.transpiler import generate_preset_pass_manager
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit_ibm_runtime import EstimatorOptions
from qiskit_ibm_runtime import EstimatorV2 as Estimator
from matplotlib import pyplot as plt
# Uncomment the next line if you want to use a simulator:
# from qiskit_ibm_runtime.fake_provider import FakeBelemV2


# Create a new circuit with two qubits
qc = QuantumCircuit(2)

# Add a Hadamard gate to qubit 0
qc.h(0)

# Perform a controlled-X gate on qubit 1, controlled by qubit 0
qc.cx(0, 1)

# Return a drawing of the circuit using MatPlotLib ("mpl").
# These guides are written by using Jupyter notebooks, which
# display the output of the last line of each cell.
# If you're running this in a script, use `print(qc.draw())` to
# print a text drawing.
qc.draw("mpl")

# %%
# Set up six different observables.

observables_labels = ["IZ", "IX", "ZI", "XI", "ZZ", "XX"]
observables = [SparsePauliOp(label) for label in observables_labels]

# %%
service = QiskitRuntimeService()

backend = service.least_busy(simulator=False, operational=True)

# Convert to an ISA circuit and layout-mapped observables.
pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(qc)

isa_circuit.draw("mpl", idle_wires=False)
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/qiskit_ibm_runtime/accounts/account.py in list_instances(self)
#     351             try:
# --> 352                 result = client.search(
#     353                     query="service_name:quantum-computing",
#
# /usr/local/lib/python3.12/dist-packages/ibm_platform_services/global_search_v2.py in search(self, query, fields, search_cursor, x_request_id, x_correlation_id, account_id, limit, timeout, sort, is_deleted, is_reclaimed, impersonate_user, can_tag, is_project_resource, **kwargs)
#     227         url = '/v3/resources/search'
# --> 228         request = self.prepare_request(
#     229             method='POST',
#
# /usr/local/lib/python3.12/dist-packages/ibm_cloud_sdk_core/base_service.py in prepare_request(self, method, url, headers, params, data, files, **kwargs)
#     440
# --> 441         self.authenticator.authenticate(request)
#     442
#
# /usr/local/lib/python3.12/dist-packages/ibm_cloud_sdk_core/authenticators/iam_request_based_authenticator.py in authenticate(self, req)
#      63         headers = req.get('headers')
# ---> 64         bearer_token = self.token_manager.get_token()
#      65         headers['Authorization'] = 'Bearer {0}'.format(bearer_token)
#
# /usr/local/lib/python3.12/dist-packages/ibm_cloud_sdk_core/token_managers/token_manager.py in get_token(self)
#      81             logger.debug('Performing synchronous token fetch')
# ---> 82             self.paced_request_token()
#      83
#
# /usr/local/lib/python3.12/dist-packages/ibm_cloud_sdk_core/token_managers/token_manager.py in paced_request_token(self)
#     140             if not request_active:
# --> 141                 token_response = self.request_token()
#     142                 self._save_token_info(token_response)
#
# /usr/local/lib/python3.12/dist-packages/ibm_cloud_sdk_core/token_managers/iam_request_based_token_manager.py in request_token(self)
#     126         logger.debug('Invoking IAM get_token operation: %s', request_url)
# --> 127         response = self._request(
#     128             method='POST',
#
# /usr/local/lib/python3.12/dist-packages/ibm_cloud_sdk_core/token_managers/jwt_token_manager.py in _request(self, method, url, headers, params, data, auth_tuple, **kwargs)
#      90
# ---> 91         raise ApiException(response.status_code, http_response=response)
#
# ApiException: Error: Provided API key could not be found., Status code: 400
#
# The above exception was the direct cause of the following exception:
#
# InvalidAccountError                       Traceback (most recent call last)
# /tmp/ipykernel_676/4046909820.py in <cell line: 0>()
# ----> 1 service = QiskitRuntimeService()
#       2
#       3 backend = service.least_busy(simulator=False, operational=True)
#       4
#       5 # Convert to an ISA circuit and layout-mapped observables.
#
# /usr/local/lib/python3.12/dist-packages/qiskit_ibm_runtime/qiskit_runtime_service.py in __init__(self, channel, token, url, filename, name, instance, proxies, verify, private_endpoint, url_resolver, region, plans_preference, tags)
#     224         if self._instance_auto:
#     225             instance = None
# --> 226         self._account = self._discover_account(
#     227             token=token,
#     228             url=url,
#
# /usr/local/lib/python3.12/dist-packages/qiskit_ibm_runtime/qiskit_runtime_service.py in _discover_account(self, token, url, instance, channel, filename, name, proxies, verify)
#     478             and not is_crn(account.instance)
#     479         ):
# --> 480             account.instance = self._get_crn_from_instance_name(
#     481                 account=account, instance=account.instance
#     482             )
#
# /usr/local/lib/python3.12/dist-packages/qiskit_ibm_runtime/qiskit_runtime_service.py in _get_crn_from_instance_name(self, account, instance)
#     490         """Get the crn from the instance service name."""
#     491         if not self._all_instances:
# --> 492             self._all_instances = account.list_instances()
#     493         matching_instances = [item for item in self._all_instances if item["name"] == instance]
#     494         if matching_instances:
#
# /usr/local/lib/python3.12/dist-packages/qiskit_ibm_runtime/accounts/account.py in list_instances(self)
#     365                 ).get_result()
#     366             except Exception as ex:
# --> 367                 raise InvalidAccountError(
#     368                     "Unable to retrieve instances. "
#     369                     "Please check that you are using a valid API token."
#
# InvalidAccountError: 'Unable to retrieve instances. Please check that you are using a valid API token.'

# %%
# Construct the Estimator instance.

estimator = Estimator(mode=backend)
estimator.options.resilience_level = 1
estimator.options.default_shots = 5000

mapped_observables = [
    observable.apply_layout(isa_circuit.layout) for observable in observables
]

# One pub, with one circuit to run against five different observables.
job = estimator.run([(isa_circuit, mapped_observables)])

# Use the job ID to retrieve your job data later
print(f">>> Job ID: {job.job_id()}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_676/1408773715.py in <cell line: 0>()
#       1 # Construct the Estimator instance.
#       2
# ----> 3 estimator = Estimator(mode=backend)
#       4 estimator.options.resilience_level = 1
#       5 estimator.options.default_shots = 5000
#
# NameError: name 'backend' is not defined

# %%
# This is the result of the entire submission.  You submitted one Pub,
# so this contains one inner result (and some metadata of its own).
job_result = job.result()

# This is the result from our single pub, which had six observables,
# so contains information on all six.
pub_result = job.result()[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_676/666296812.py in <cell line: 0>()
#       1 # This is the result of the entire submission.  You submitted one Pub,
#       2 # so this contains one inner result (and some metadata of its own).
# ----> 3 job_result = job.result()
#       4
#       5 # This is the result from our single pub, which had six observables,
#
# NameError: name 'job' is not defined

# %%
# Use the following code instead if you want to run on a simulator:

from qiskit_ibm_runtime.fake_provider import FakeBelemV2
backend = FakeBelemV2()
estimator = Estimator(backend)

# Convert to an ISA circuit and layout-mapped observables.

pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(qc)
mapped_observables = [
    observable.apply_layout(isa_circuit.layout) for observable in observables
]

job = estimator.run([(isa_circuit, mapped_observables)])
result = job.result()

# This is the result of the entire submission. You submitted one Pub,
# so this contains one inner result (and some metadata of its own).

job_result = job.result()

# This is the result from our single pub, which had five observables,
# so contains information on all five.

pub_result = job.result()[0]

# %%
# Plot the result

values = pub_result.data.evs

errors = pub_result.data.stds

# plotting graph
plt.plot(observables_labels, values, "-o")
plt.xlabel("Observables")
plt.ylabel("Values")
plt.show()
